# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
df = pd.read_csv("intern_dataset.csv")

# %%
df.head()
# Out:
#                       Time       Signal1   Signal2 Label
# 0  2017-08-14 11:37:49.791  33668.091913  0.856726     A
# 1  2017-08-14 11:37:49.801  32564.903040  0.856705     A
# 2  2017-08-14 11:37:49.811  31454.043305  0.856683     A
# 3  2017-08-14 11:37:49.821  30335.387166  0.856659     A
# 4  2017-08-14 11:37:49.831  29207.142938  0.856634     A

# %%
df.shape
# Out:
# (912000, 4)

# %% [markdown]
# # Data Exploration

# %%
df.columns
# Out:
# Index(['Time', 'Signal1', 'Signal2', 'Label'], dtype='object')

# %% [markdown]
# information about the data

# %%
df.info
# Out:
# <bound method DataFrame.info of                            Time       Signal1   Signal2 Label
# 0       2017-08-14 11:37:49.791  33668.091913  0.856726     A
# 1       2017-08-14 11:37:49.801  32564.903040  0.856705     A
# 2       2017-08-14 11:37:49.811  31454.043305  0.856683     A
# 3       2017-08-14 11:37:49.821  30335.387166  0.856659     A
# 4       2017-08-14 11:37:49.831  29207.142938  0.856634     A
# ...                         ...           ...       ...   ...
# 911995  2020-01-04 10:55:49.186  34673.811155  0.151395     C
# 911996  2020-01-04 10:55:49.196  34672.951723  0.151385     C
# 911997  2020-01-04 10:55:49.206  34671.967555  0.151373     C
# 911998  2020-01-04 10:55:49.216  34670.877944  0.151359     C
# 911999  2020-01-04 10:55:49.226  34669.694865  0.151342     C
#
# [912000 rows x 4 columns]>

# %% [markdown]
# checking if there is any null value

# %%
df.isnull().sum()
# Out:
# Time       0
# Signal1    0
# Signal2    0
# Label      0
# dtype: int64

# %% [markdown]
# so we can see that we do not have any null value

# %%
plt.figure(figsize=(6,4))
sn.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Hence we now clearly see that we do not have any missing values through graph.

# %%
plt.style.use('ggplot')

# %%
sn.pairplot(df)

# %% [markdown]
# ## Analyzing data of class A

# %%
a= df[df['Label']=='A']
print(a)
# Out:
#                            Time       Signal1   Signal2 Label
# 0       2017-08-14 11:37:49.791  33668.091913  0.856726     A
# 1       2017-08-14 11:37:49.801  32564.903040  0.856705     A
# 2       2017-08-14 11:37:49.811  31454.043305  0.856683     A
# 3       2017-08-14 11:37:49.821  30335.387166  0.856659     A
# 4       2017-08-14 11:37:49.831  29207.142938  0.856634     A
# ...                         ...           ...       ...   ...
# 317995  2017-09-19 12:13:44.148  65807.274554  0.245727     A
# 317996  2017-09-19 12:13:44.158  65692.473335  0.245748     A
# 317997  2017-09-19 12:13:44.168  65472.863928  0.245770     A
# 317998  2017-09-19 12:13:44.178  65147.555563  0.245792     A
# 317999  2017-09-19 12:13:44.188  64715.020885  0.245815     A
#
# [318000 rows x 4 columns]

# %% [markdown]
# here are all the the rows and columns of class 'A'

# %%
plt.figure(figsize=(8,6))
df[df['Label']=='A'].plot(x='Time',y='Signal1')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
plt.figure(figsize=(8,6))
df[df['Label']=='A'].plot(x='Time',y='Signal2')
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# These 2 graphs shows the data of A class of Signal1 and Signal2 respectiveley.

# %%
plt.figure(figsize=(8,6))
df[df['Label']=='A'].plot(x='Signal1',y='Signal2')
# Out:
# <AxesSubplot:xlabel='Signal1'>

# %% [markdown]
# Above three graphs are of class 'A' ,where, 1st graph graph shows the relationship of class 1 with time vs. signal1, 2nd shows time vs. signal2, and 3rd shows signal1 and signal2.

# %% [markdown]
# ## Analyzing data of class B

# %%
b= df[df['Label']=='B']
print(b)
# Out:
#                            Time       Signal1   Signal2 Label
# 510000  2017-09-19 12:18:25.698  47842.554832  0.499167     B
# 510001  2017-09-19 12:18:25.708  48258.447534  0.499155     B
# 510002  2017-09-19 12:18:25.718  48654.923757  0.499143     B
# 510003  2017-09-19 12:18:25.728  49015.036918  0.499130     B
# 510004  2017-09-19 12:18:25.738  49323.169365  0.499117     B
# ...                         ...           ...       ...   ...
# 821995  2017-09-26 12:56:48.364  30046.252223  0.546830     B
# 821996  2017-09-26 12:56:48.374  32747.288036  0.546804     B
# 821997  2017-09-26 12:56:48.384  35648.107903  0.546778     B
# 821998  2017-09-26 12:56:48.394  38646.426455  0.546754     B
# 821999  2017-09-26 12:56:48.404  41636.075714  0.546730     B
#
# [312000 rows x 4 columns]

# %%
plt.figure(figsize=(8,6))
df[df['Label']=='B'].plot(x='Time',y='Signal1')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
plt.figure(figsize=(8,6))
df[df['Label']=='B'].plot(x='Time',y='Signal2')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
plt.figure(figsize=(8,6))
df[df['Label']=='B'].plot(x='Signal1',y='Signal2')
# Out:
# <AxesSubplot:xlabel='Signal1'>

# %% [markdown]
# These 3 above graph shows the graph of class 'B'. 1st graph graph shows the relationship of class 1 with time vs. signal1, 2nd shows time vs. signal2, and 3rd shows signal1 and signal2.
#
#
# Now we can clearly compare that class A graph are more denser than than the class B.
#
#
# Now next let us see the grpahs of class C then we can compare all three classes together.

# %% [markdown]
# ## Analyzing data of class C

# %%
c= df[df['Label']=='C']
print(c)
# Out:
#                            Time       Signal1   Signal2 Label
# 318000  2017-08-12 11:08:25.785  22719.403196  0.123263     C
# 318001  2017-08-12 11:08:25.795  23608.265317  0.123268     C
# 318002  2017-08-12 11:08:25.805  24524.544926  0.123273     C
# 318003  2017-08-12 11:08:25.815  25479.836092  0.123279     C
# 318004  2017-08-12 11:08:25.825  26475.848059  0.123285     C
# ...                         ...           ...       ...   ...
# 911995  2020-01-04 10:55:49.186  34673.811155  0.151395     C
# 911996  2020-01-04 10:55:49.196  34672.951723  0.151385     C
# 911997  2020-01-04 10:55:49.206  34671.967555  0.151373     C
# 911998  2020-01-04 10:55:49.216  34670.877944  0.151359     C
# 911999  2020-01-04 10:55:49.226  34669.694865  0.151342     C
#
# [282000 rows x 4 columns]

# %%
plt.figure(figsize=(8,6))
df[df['Label']=='C'].plot(x='Time',y='Signal1')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
plt.figure(figsize=(8,6))
df[df['Label']=='C'].plot(x='Time',y='Signal2')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
plt.figure(figsize=(8,6))
df[df['Label']=='C'].plot(x='Signal1',y='Signal2')
# Out:
# <AxesSubplot:xlabel='Signal1'>

# %% [markdown]
# These 3 above graph shows the graph of class 'B'. 1st graph graph shows the relationship of class 1 with time vs. signal1, 2nd shows time vs. signal2, and 3rd shows signal1 and signal2.

# %% [markdown]
# Hence now we can infer that from all three classes i.e., A, B, and C . A class is the most densed i.e., most complex of all three,while C class is denser than B ,hence we get(A>C>B)
